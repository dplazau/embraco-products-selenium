# %%
import pandas as pd

# %%
df = pd.read_csv("COMPRESSORS-2022-04-23-13-58-12.csv")

# %%
df.head()
# Out:
#         Model Refrigerant Frequency / Rotation   HP  \
# 0    EG130HLR      R-134a                50 Hz  1/3
# 1    EG130HLR      R-134a                50 Hz  1/3
# 2    EG130HLR      R-134a                50 Hz  1/3
# 3  EGAS100CLP      R-600a                60 Hz  1/3
# 4  EGAS100CLP      R-600a                60 Hz  1/3
#
#                 Power Supply Application Standard Condition Tested Conditions  \
# 0            220-240 V 50 Hz         LBP             ASHRAE               LBP
# 1            220-240 V 50 Hz         LBP            ARI 540               LBP
# 2            220-240 V 50 Hz         LBP            EN12900               LBP
# 3  220 V 50 Hz / 220 V 60 Hz         LBP             ASHRAE               LBP
# 4  220 V 50 Hz / 220 V 60 Hz         LBP            ARI 540               LBP
#
#    Capacity  Efficiency Displacement Motor Type Starting Torque
# 0       301        1.36    10.61 cm³  RSIR/CSIR             LST
# ...
